# %%
import torch

torch.manual_seed(42)  # Set random seed for reproducibility

GPU = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Tensor
x = torch.rand(2, 3).to(GPU) # Create a random tensor on the specified device
y = torch.ones_like(x).to(GPU) # Create a tensor of ones with the same shape as x
z = x + y
print(z)

#auto grad
x = torch.rand(2, 3, device=GPU, requires_grad=True) # Create a random tensor on the specified device

y = x**2
y.sum().backward() # d(sum())/dx
print(x.grad)  # Should print the gradient of y with respect to x

print(x.shape, x.dtype, x.device)
# Out:
# tensor([[1.8823, 1.9150, 1.3829],
#         [1.9593, 1.3904, 1.6009]], device='cuda:0')
# tensor([[1.2259, 0.0201, 0.7968],
#         [0.0806, 0.3125, 0.9649]], device='cuda:0')
# torch.Size([2, 3]) torch.float32 cuda:0

# %%
print("GPU Available:", torch.cuda.is_available())
print("GPU Name:", torch.cuda.get_device_name(0))
# Out:
# GPU Available: True
# GPU Name: NVIDIA GeForce RTX 3070

# %%
import torch.nn as nn

class SimpleNN(nn.Module):
    def __init__(self):
        super(SimpleNN, self).__init__()
        self.fc1 = nn.Linear(3, 5)  # First layer: input size 3, output size 5
        self.fc2 = nn.Linear(5, 2)  # Second layer: input size 5, output size 2

    def forward(self, x):
        x = torch.relu(self.fc1(x))  # Apply ReLU activation after first layer
        x = self.fc2(x)               # Output layer
        return x
    
criterion = nn.CrossEntropyLoss()  # Loss function for classification tasks
optimizer = torch.optim.Adam(SimpleNN().parameters(), lr=0.001)  # Optimizer for training

# %%
from sklearn.metrics import f1_score, precision_score, recall_score

for epoch in range(3):
    model.train()
    for images, labels in train_loader:
        images, labels = images.to(device), labels.to(device)

        optimizer.zero_grad()
        outputs = model(images)
        loss = criterion(outputs, labels)
        accuracy = (outputs.argmax(dim=1) == labels).float().mean()
        f1 = f1_score(labels.cpu(), outputs.argmax(dim=1).cpu(), average='weighted')
        precision = precision_score(labels.cpu(), outputs.argmax(dim=1).cpu(), average='weighted')
        recall = recall_score(labels.cpu(), outputs.argmax(dim=1).cpu(), average='weighted')
        loss.backward()
        optimizer.step()
    print(f'Epoch [{epoch+1}/3], Loss: {loss.item():.4f}, accuracy: {accuracy:.4f}, f1: {f1:.4f}, precision: {precision:.4f}, recall: {recall:.4f}')
# Out:
# c:\Users\Shohan\miniconda3\envs\learn\lib\site-packages\sklearn\metrics\_classification.py:1706: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\Shohan\miniconda3\envs\learn\lib\site-packages\sklearn\metrics\_classification.py:1706: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\Shohan\miniconda3\envs\learn\lib\site-packages\sklearn\metrics\_classification.py:1706: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
# ...
